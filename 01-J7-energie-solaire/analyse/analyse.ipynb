# %% [markdown]
# # Analyse des données d'expérience
#
# Expérience: J7 Energie Solaire
#
# Date: 2023-09-30

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Save figs for latex
import matplotlib as mpl
import tikzplotlib as tikz

# %% [markdown]
# ## Expérience 2: Puissance max

# %% [markdown]
# ### Amorphe

# %%
amorphed40 = np.loadtxt("../data/Ir(Ud),amorphe,d=40cm.csv", delimiter=",", skiprows=1, dtype=float)
amorphed70 = np.loadtxt("../data/Ir(Ud),amorphe,d=70cm.csv", delimiter=",", skiprows=1, dtype=float)

# %%
plt.scatter(amorphed40[:,1], amorphed40[:,2], marker="+", label="d = 40 cm")
plt.scatter(amorphed70[:,1], amorphed70[:,2], marker="x", label="d = 70 cm")
plt.legend()
# plt.title("$I_r(U_d)$, Cellule Amorphe")
plt.xlabel("$U_d$ [V]")
plt.ylabel("$I_r$ [mA]")
tikz.save("../plots/amorpheI(U).tikz")

# %%
# Puissances
# [W] = [V] * [A]
puis_amorphed40 = amorphed40[:,1] * amorphed40[:,2] * 1e-3
puis_amorphed70 = amorphed70[:,1] * amorphed70[:,2] * 1e-3

plt.scatter(amorphed40[:,1], puis_amorphed40, marker="+", label="d = 40 cm")
plt.scatter(amorphed70[:,1], puis_amorphed70, marker="x", label="d = 70 cm")
plt.legend(loc='lower left')
# plt.title("$P(U_d)$, amorphe")
plt.xlabel("$U_d$ [V]")
plt.ylabel("Puissance [W]")
tikz.save("../plots/amorpheP(U).tikz")

# %% [markdown]
# ### Monocristallin

# %%
monod40 = np.loadtxt("../data/Ir(Ud),monocristallin,d=40cm.csv", delimiter=",", skiprows=1, dtype=float)
monod70 = np.loadtxt("../data/Ir(Ud),monocristallin,d=70cm.csv", delimiter=",", skiprows=1, dtype=float)

# %%
plt.scatter(monod40[:,1], monod40[:,2], marker="+", label="d = 40 cm")
plt.scatter(monod70[:,1], monod70[:,2], marker="x", label="d = 70 cm")
# plt.title("$I_r(U_d)$, Cellule Monocristallin")
plt.xlabel("$U_d$ [V]")
plt.ylabel("$I_r$ [mA]")
tikz.save("../plots/monocristallinI(U).tikz")

# %%
# Puissances
# [W] = [V] * [A]
puis_monod40 = monod40[:,1] * monod40[:,2] * 1e-3
puis_monod70 = monod70[:,1] * monod70[:,2] * 1e-3

plt.scatter(monod40[:,1], puis_monod40, marker="+", label="d = 40 cm")
plt.scatter(monod70[:,1], puis_monod70, marker="x", label="d = 70 cm")
plt.legend(loc='lower left')
# plt.title("$P(U_d)$, Cellule Monocristalline")
plt.xlabel("$U_d$ [V]")
plt.ylabel("Puissance [W]")
tikz.save("../plots/monocristallinP(U).tikz")

# %% [markdown]
# ### Polycristallin

# %%
polyd40 = np.loadtxt("../data/Ir(Ud),polycristallin,d=40cm.csv", delimiter=",", skiprows=1, dtype=float)
polyd70 = np.loadtxt("../data/Ir(Ud),polycristallin,d=70cm.csv", delimiter=",", skiprows=1, dtype=float)

# %%
plt.scatter(polyd40[:,1], polyd40[:,2], marker='+', label="d = 40 cm")
plt.scatter(polyd70[:,1], polyd70[:,2], marker='x', label="d = 70 cm")
plt.legend()
# plt.title("$I_r(U_d)$, Cellule Polycristalline")
plt.xlabel("$U_d$ [V]")
plt.ylabel("$I_r$ [mA]")
tikz.save("../plots/polycristallinI(U).tikz")

# %%
# Puissances
# [W] = [V] * [A]
puis_polyd40 = polyd40[:,1] * polyd40[:,2] * 1e-3
puis_polyd70 = polyd70[:,1] * polyd70[:,2] * 1e-3

plt.scatter(polyd40[:,1], puis_polyd40, marker="+", label="d = 40 cm")
plt.scatter(polyd70[:,1], puis_polyd70, marker="x", label="d = 70 cm")
plt.legend(loc='lower left')
# plt.title("$P(U_d)$, Cellule Polycristalline")
plt.xlabel("$U_d$ [V]")
plt.ylabel("Puissance [W]")
tikz.save("../plots/polycristallinP(U).tikz")
