# %% [markdown]
# # Nom

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from options import *
mpl.rcParams.update(rcParams)

# %% [markdown]
# # Ag
#
# I constant = (1.972 $\pm$ 0.001) A
#
# B constant = (343 $\pm$ 6) mT

# %%
Ag_B = np.loadtxt("../data/Ag_5branch_B.csv", delimiter=",", skiprows=1)

plt.scatter(Ag_B[:,0], Ag_B[:,1])
plt.xlabel(r"$B$ [\si{\milli \tesla}]")
plt.ylabel(r"$V_H$ [\si{\milli \volt}]")
plt.grid()

# %%
Ag_I = np.loadtxt("../data/Ag_5branch_I.csv", delimiter=",", skiprows=1)

plt.scatter(Ag_I[:,0], Ag_I[:,1])
plt.xlabel(r"$I$ [\si{\ampere}]")
plt.ylabel(r"$V_H$ [\si{\milli \volt}]")
plt.grid()

# %% [markdown]
# # Cu
#
# I constant = (1.989 $\pm$ 0.001) A
#
# B constant = (353 $\pm$ 7) mT

# %%
Cu_B = np.loadtxt("../data/Cu_5branch_B.csv", delimiter=",", skiprows=1)

plt.scatter(Cu_B[:,0], Cu_B[:,1])
plt.xlabel(r"$B$ [\si{\milli \tesla}]")
plt.ylabel(r"$V_H$ [\si{\milli \volt}]")
plt.grid()

# %% [markdown]
# # Bi
#
# I constant = (1.973 $\pm$ 0.001) A
#
# B constant = (369 $\pm$ 7) mT

# %%
Bi_B = np.loadtxt("../data/Bi_5branch_B.csv", delimiter=",", skiprows=1)

plt.scatter(Bi_B[:,0], Bi_B[:,1])
plt.xlabel(r"$B$ [\si{\milli \tesla}]")
plt.ylabel(r"$V_H$ [\si{\milli \volt}]")
plt.grid()
